# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Apartado a

# %%
col = ['i' , 'd']
datos = pd.read_table('7-34-a-app.dat', sep= "\s+" , names = col , header = None)

datos
# Out:
#         i          d
# 0       1   1.000000
# 1       2   1.375985
# 2       3   1.788854
# 3       4   2.046134
# 4       5   2.335237
# ..    ...        ...
# 995   996  30.223721
# 996   997  31.891064
# 997   998  32.269283
# 998   999  31.790983
# 999  1000  31.012148
#
# [1000 rows x 2 columns]

# %%
plt.style.use('ggplot')

a = np.linspace(0 , 32 , 5000)

b = a  

plt.figure(figsize = (16,9))

plt.plot(np.sqrt(datos.i), datos.d , color = 'b' , linewidth = '1' , label= '$d_{rms}$' )
plt.plot(a , b, color = 'r' , linewidth = '1.9' , label = 'recta $y=x$' )

plt.title('Distancia $d_{rms}$ al hotel calles de lado $L=$1 m' , fontsize = '29')
plt.xlabel('$\sqrt{N}$' , color = 'black' , fontsize = '25' )
plt.ylabel('$d_{rms}$ (m)' , color = 'black' , fontsize = '25' )

plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)

plt.legend(loc = "best" , prop={'size':18} , shadow = True , edgecolor='black' , facecolor = 'wheat' )

plt.savefig( '7-34-a-app.pdf' )

# %% [markdown]
# #Apartado b

# %%
col = ['i' , 'd']

datos = pd.read_table('7-34-b-app.dat', sep= "\s+" , names = col , header = None)
datos
# Out:
#         i          d
# 0       1   0.599500
# 1       2   0.824008
# 2       3   1.101499
# 3       4   1.194368
# 4       5   1.297619
# ..    ...        ...
# 995   996  19.004995
# 996   997  19.490585
# 997   998  18.774036
# 998   999  18.975412
# 999  1000  18.598454
#
# [1000 rows x 2 columns]

# %%
plt.figure(figsize = (16,9))

x = np.linspace(0,31 , 1000)
y = 0.6*x

plt.plot(np.sqrt(datos.i) , datos.d, color = 'b' , linewidth = '1' , label = '$d_{rms}$')
plt.plot(x , y , linewidth = '2.5' , label= 'recta $y =0.6x $')

plt.title('Distancia $d_{rms}$ distribución uniforme entre $L_{1}$=0.5 m y $L_{2}$=0.7 m' , fontsize = '29')
plt.xlabel('$\sqrt{N}$' , color = 'black' , fontsize = '25' )
plt.ylabel('$d_{rms}$ (m)' , color = 'black' , fontsize = '25' )

plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)

plt.legend(loc = "best" , prop={'size':18} , shadow = True , edgecolor='black' , facecolor = 'wheat' )

plt.savefig( '7-34-b-app.pdf' )

# %% [markdown]
# # apartado c

# %%
col = ['i' , 'd']

datos = pd.read_table('7-34-c-app.dat', sep= "\s+" , names = col , header = None)
datos
# Out:
#         i          d
# 0       1   0.874331
# 1       2   1.203132
# 2       3   1.386162
# 3       4   1.733192
# 4       5   1.857411
# ..    ...        ...
# 995   996  27.077949
# 996   997  25.596333
# 997   998  26.396503
# 998   999  26.514008
# 999  1000  26.642223
#
# [1000 rows x 2 columns]

# %%
plt.figure(figsize = (16,9))

a = np.linspace(0,32,1000)
b = 0.85*a

plt.plot(np.sqrt(datos.i) , datos.d , linewidth = '2.5' , color = 'b' , label = '$d_{rms}$')
plt.plot(a , b , linewidth = '2.5' , label = 'recta $y=0.85x$')


plt.title('Distancia $d_{rms}$ distribución exponencial decreciente \n de valor medio $<L>$ = 60 cm ' , fontsize = '29')
plt.xlabel('$\sqrt{N}$' , color = 'black' , fontsize = '25' )
plt.ylabel('$d_{rms}$ (m)' , color = 'black' , fontsize = '25')

plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)

plt.legend(loc = "best" , prop={'size':18} , shadow = True , edgecolor='black' , facecolor = 'wheat' )

plt.savefig( '7-34-c-app.pdf' )

# %%
# Apartado d

# %%
col = ['x' , 'y']

# Leo los archivos del primer experimento

a1 = pd.read_table('apartado-d/7-34-a1-app.dat', sep= "\s+" , names = col , header = None)
a2 = pd.read_table('apartado-d/7-34-a2-app.dat', sep= "\s+" , names = col , header = None)
a3 = pd.read_table('apartado-d/7-34-a3-app.dat', sep= "\s+" , names = col , header = None)
a4 = pd.read_table('apartado-d/7-34-a4-app.dat', sep= "\s+" , names = col , header = None)
a5 = pd.read_table('apartado-d/7-34-a5-app.dat', sep= "\s+" , names = col , header = None)

# Leo los archivos del segundo experimento, distribucion lineal

b1 = pd.read_table('apartado-d/7-34-b1-app.dat', sep= "\s+" , names = col , header = None)
b2 = pd.read_table('apartado-d/7-34-b2-app.dat', sep= "\s+" , names = col , header = None)
b3 = pd.read_table('apartado-d/7-34-b3-app.dat', sep= "\s+" , names = col , header = None)
b4 = pd.read_table('apartado-d/7-34-b4-app.dat', sep= "\s+" , names = col , header = None)
b5 = pd.read_table('apartado-d/7-34-b5-app.dat', sep= "\s+" , names = col , header = None)

# Leo los archivos del tercer experimento, distribucion exponencial

c1 = pd.read_table('apartado-d/7-34-c1-app.dat', sep= "\s+" , names = col , header = None)
c2 = pd.read_table('apartado-d/7-34-c2-app.dat', sep= "\s+" , names = col , header = None)
c3 = pd.read_table('apartado-d/7-34-c3-app.dat', sep= "\s+" , names = col , header = None)
c4 = pd.read_table('apartado-d/7-34-c4-app.dat', sep= "\s+" , names = col , header = None)
c5 = pd.read_table('apartado-d/7-34-c5-app.dat', sep= "\s+" , names = col , header = None)

da1 = np.sqrt(a1.x**2 + a1.y**2)
da2 = np.sqrt(a2.x**2 + a2.y**2)
da3 = np.sqrt(a3.x**2 + a2.y**2)
da4 = np.sqrt(a4.x**2 + a2.y**2)
da5 = np.sqrt(a5.x**2 + a2.y**2)

db1 = np.sqrt(b1.x**2 + b1.y**2)
db2 = np.sqrt(b2.x**2 + b2.y**2)
db3 = np.sqrt(b3.x**2 + b2.y**2)
db4 = np.sqrt(b4.x**2 + b2.y**2)
db5 = np.sqrt(b5.x**2 + b2.y**2)

dc1 = np.sqrt(c1.x**2 + c1.y**2)
dc2 = np.sqrt(c2.x**2 + c2.y**2)
dc3 = np.sqrt(c3.x**2 + c2.y**2)
dc4 = np.sqrt(c4.x**2 + c2.y**2)
dc5 = np.sqrt(c5.x**2 + c2.y**2)

# %%
fig = plt.figure(figsize = (16+4,9+4))

plt.style.use('ggplot')

ax = fig.gca()
ax.set_xticks(np.arange(-20, 50, 1))
ax.set_yticks(np.arange(-20, 50, 1));

plt.plot(a1.x , a1.y , color = 'r' , label = 'Trayectoria 1')
plt.plot(0,0, 'r^', mew=1, ms=15 )
plt.plot(a1.x[499],a1.y[499], 'r^', mew=1, ms=20 )

plt.plot(a2.x , a2.y , color = 'dodgerblue', label = 'Trayectoria 2')
plt.plot(0,0, 'g^', mew=1, ms=15 )
plt.plot(a2.x[499],a2.y[499], '^', mew=1, ms=20 ,color = 'dodgerblue')

plt.plot(a3.x , a3.y , color = 'b', label = 'Trayectoria 3')
plt.plot(0,0, 'b^', mew=1, ms=15 )
plt.plot(a3.x[499],a3.y[499], 'b^', mew=1, ms=20 )

plt.plot(a4.x , a4.y , color = 'y', label = 'Trayectoria 4')
plt.plot(0,0, 'y^', mew=1, ms=15 )
plt.plot(a4.x[499],a4.y[499], 'y^', mew=1, ms=20 )

plt.plot(a5.x , a5.y , color = 'k', label = 'Trayectoria 5')
plt.plot(0,0, 'k^', mew=1, ms=15 )
plt.plot(a5.x[499],a5.y[499], 'k^', mew=1, ms=20 )

plt.title('5 trayectorias N=500 pasos $L$=1 m' , fontsize = '29')
plt.xlabel('$x$ (m)' , color = 'black' , fontsize = '25' )
plt.ylabel('$y$ (m)' , color = 'black' , fontsize = '25' )

plt.legend(loc = "best" , prop={'size':16.4} , shadow = True , edgecolor='black' , facecolor = 'wheat' )

plt.savefig( '7-34-ca-app.pdf' )

# %%
fig = plt.figure(figsize = (16+4,9+4))

# ax = fig.gca()
# ax.set_xticks(np.arange(-20, 50, 1))
# ax.set_yticks(np.arange(-20, 50, 1));

plt.plot(b1.x , b1.y , color = 'r', label = 'Trayectoria 1')
plt.plot(0,0, 'r^', mew=1, ms=15 )
plt.plot(b1.x[499],b1.y[499], 'r^', mew=1, ms=30 )

plt.plot(b2.x , b2.y , color = 'dodgerblue', label = 'Trayectoria 2')
plt.plot(0,0, 'g^', mew=1, ms=15 )
plt.plot(b2.x[499],b2.y[499], '^', mew=1, ms=30 ,color = 'dodgerblue')

plt.plot(b3.x , b3.y , color = 'b', label = 'Trayectoria 3')
plt.plot(0,0, 'b^', mew=1, ms=15 )
plt.plot(b3.x[499],b3.y[499], 'b^', mew=1, ms=30 )

plt.plot(b4.x , b4.y , color = 'y',  label = 'Trayectoria 4')
plt.plot(0,0, 'y^', mew=1, ms=15 )
plt.plot(b4.x[499],b4.y[499], 'y^', mew=1, ms=30 )

plt.plot(b5.x , b5.y , color = 'k', label = 'Trayectoria 5')
plt.plot(0,0, 'k^', mew=1, ms=15 )
plt.plot(b5.x[499],b5.y[499], 'k^', mew=1, ms=30 )

plt.grid()

plt.title('5 trayectorias distribución uniforme N=500' , fontsize = '29')
plt.xlabel('$x$ (m)' , color = 'black' , fontsize = '25' )
plt.ylabel('$y$ (m)' , color = 'black' , fontsize = '25' )

plt.legend(loc = "best" , prop={'size':18} , shadow = True , edgecolor='black' , facecolor = 'wheat' )

plt.savefig( '7-34-cb-app.pdf' )

# %%
fig = plt.figure(figsize = (16+4,9+4))

# ax = fig.gca()
# ax.set_xticks(np.arange(-20, 50, 1))
# ax.set_yticks(np.arange(-20, 50, 1));

plt.plot(c1.x , c1.y , color = 'r' , label = 'Trayectoria 1')
plt.plot(0,0, 'r^', mew=1, ms=15 )
plt.plot(c1.x[499],c1.y[499], 'r^', mew=1, ms=30 )

plt.plot(c2.x , c2.y , color = 'dodgerblue', label = 'Trayectoria 2')
plt.plot(0,0, 'g^', mew=1, ms=15 )
plt.plot(c2.x[499],c2.y[499], '^', mew=1, ms=30 ,color = 'dodgerblue')

plt.plot(c3.x , c3.y , color = 'b', label = 'Trayectoria 3')
plt.plot(0,0, 'b^', mew=1, ms=15 )
plt.plot(c3.x[499],c3.y[499], 'b^', mew=1, ms=30 )

plt.plot(c4.x , c4.y , color = 'y', label = 'Trayectoria 4')
plt.plot(0,0, 'y^', mew=1, ms=15 )
plt.plot(c4.x[499],c4.y[499], 'y^', mew=1, ms=30 )

plt.plot(c5.x , c5.y , color = 'k', label = 'Trayectoria 5')
plt.plot(0,0, 'k^', mew=1, ms=15 )
plt.plot(c5.x[499],c5.y[499], 'k^', mew=1, ms=30 )

plt.grid()

plt.title('5 trayectorias distribución exponencial N=500' , fontsize = '29')
plt.xlabel('$x$ (m)' , color = 'black' , fontsize = '25' )
plt.ylabel('$y$ (m)' , color = 'black' , fontsize = '25' )

plt.legend(loc = "best" , prop={'size':18} , shadow = True , edgecolor='black' , facecolor = 'wheat' )

plt.savefig( '7-34-cc-app.pdf' )

# %%
# 5 caminos diferentes para la grafica del apartado a
plt.figure(figsize=(16,9))

iteraciones = np.linspace(0 , 500 , 500)

plt.plot( np.sqrt(iteraciones), da1 , linewidth = '1.5' , color = 'r')
plt.plot(np.sqrt(iteraciones), da2 , linewidth = '1.5' , color = 'g')
plt.plot(np.sqrt(iteraciones), da3 , linewidth = '1.5' , color = 'b')
plt.plot(np.sqrt(iteraciones), da4 , linewidth = '1.5' , color = 'y')
plt.plot(np.sqrt(iteraciones), da5 , linewidth = '1.5' , color = 'k')

plt.plot(np.sqrt(iteraciones)[499] , da1[499] , 'r^', mew=1, ms=15 )
plt.plot(np.sqrt(iteraciones)[499] , da2[499] , 'g^', mew=1, ms=15 )
plt.plot(np.sqrt(iteraciones)[499] , da3[499] , 'b^', mew=1, ms=15)
plt.plot(np.sqrt(iteraciones)[499] , da4[499] , 'y^', mew=1, ms=15)
plt.plot(np.sqrt(iteraciones)[499] , da5[499] , 'k^', mew=1, ms=15)

plt.title('5 trayectorias N=500 pasos $L$=1' , fontsize = '29')
plt.xlabel('$\sqrt{N}$' , color = 'black' , fontsize = '25' )
plt.ylabel('$d_{rms}$ (m)' , color = 'black' , fontsize = '25' )

plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)

plt.savefig( '7-34-cagraf-app.pdf' )

# %%
plt.figure(figsize=(16,9))

plt.plot( np.sqrt(iteraciones), db1 , linewidth = '1.5' , color = 'r')
plt.plot(np.sqrt(iteraciones), db2 , linewidth = '1.5' , color = 'g')
plt.plot(np.sqrt(iteraciones), db3 , linewidth = '1.5' , color = 'b')
plt.plot(np.sqrt(iteraciones), db4 , linewidth = '1.5' , color = 'y')
plt.plot(np.sqrt(iteraciones), db5 , linewidth = '1.5' , color = 'k')

plt.plot(np.sqrt(iteraciones)[499] , db1[499] , 'r^', mew=1, ms=15 )
plt.plot(np.sqrt(iteraciones)[499] , db2[499] , 'g^', mew=1, ms=15 )
plt.plot(np.sqrt(iteraciones)[499] , db3[499] , 'b^', mew=1, ms=15)
plt.plot(np.sqrt(iteraciones)[499] , db4[499] , 'y^', mew=1, ms=15)
plt.plot(np.sqrt(iteraciones)[499] , db5[499] , 'k^', mew=1, ms=15)

plt.title('5 trayectorias distribución uniforme N=500' , fontsize = '29')
plt.xlabel('$\sqrt{N}$' , color = 'black' , fontsize = '25' )
plt.ylabel('$d_{rms}$ (m)' , color = 'black' , fontsize = '25' )

plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)

plt.savefig( '7-34-cbgraf-app.pdf' )

# %%
plt.figure(figsize=(16 , 9 ))


plt.plot( iteraciones, dc1 , linewidth = '1.5' , color = 'r')
plt.plot(iteraciones, dc2 , linewidth = '1.5' , color = 'g')
plt.plot(iteraciones, dc3 , linewidth = '1.5' , color = 'b')
plt.plot(iteraciones, dc4 , linewidth = '1.5' , color = 'y')
plt.plot(iteraciones, dc5 , linewidth = '1.5' , color = 'k')

plt.plot(iteraciones[499] , dc1[499] , 'r^', mew=1, ms=15 )
plt.plot(iteraciones[499] , dc2[499] , 'g^', mew=1, ms=15 )
plt.plot(iteraciones[499] , dc3[499] , 'b^', mew=1, ms=15)
plt.plot(iteraciones[499] , dc4[499] , 'y^', mew=1, ms=15)
plt.plot(iteraciones[499] , dc5[499] , 'k^', mew=1, ms=15)

plt.title('5 trayectorias distribución exponencial N=500' , fontsize = '29')
plt.xlabel('$N$' , color = 'black' , fontsize = '25' )
plt.ylabel('$d_{rms}$ (m)' , color = 'black' , fontsize = '25' )

plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)

plt.savefig( '7-34-ccgraf-app.pdf' )
