# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Apartado a

# %%
col = ['raiz' , 'd']

datos = pd.read_table('dats-a-b-c/7-34-a-app.dat', sep= "\s+" , names = col , header = None)
datos
# Out:
#              raiz           d
# 0        1.000000    1.000000
# 1        1.414214    0.000000
# 2        1.732051    1.000000
# 3        2.000000    1.414214
# 4        2.236068    1.000000
# ...           ...         ...
# 99995  316.221436  437.248199
# 99996  316.223022  436.606232
# 99997  316.224609  435.839417
# 99998  316.226196  436.482544
# 99999  316.227753  435.839417
#
# [100000 rows x 2 columns]

# %%
plt.figure(figsize = (16,9))

plt.plot(datos.raiz , datos.d )

# %%
x = np.array(datos['raiz']).reshape((-1,1))
y = np.array(datos['d'])

# %%
model = LinearRegression()

model.fit(x , y)

R_sq = model.score(x, y)

m = model.coef_            #Pendiente

ord = model.intercept_     #Ordenada en el origen

r2 = R_sq                  #Correlación

print(m) , print(ord) , print(r2)
# Out:
# [1.38899988]
# -54.99640189833039
# 0.9256152407058447
# (None, None, None)

# %%
a = np.linspace(0 , 317 , 5000)

b = 1.2*a  + ord

plt.figure(figsize = (16,9))


plt.plot(datos.raiz , datos.d )
plt.plot(a , b, color = 'r')

# %% [markdown]
# #Apartado b

# %%
col = ['i' , 'd']

datos = pd.read_table('7-34-b-app.dat', sep= "\s+" , names = col , header = None)
datos
# Out:
#             i           d
# 0           1    0.667366
# 1           2    1.156122
# 2           3    0.646135
# 3           4    1.284615
# 4           5    1.372677
# ...       ...         ...
# 99995   99996  173.023911
# 99996   99997  172.507904
# 99997   99998  172.789963
# 99998   99999  173.342270
# 99999  100000  173.487732
#
# [100000 rows x 2 columns]

# %%
plt.figure(figsize = (16,9))

x = np.linspace(0,320 , 1000)
y = 0.55*x


plt.plot(np.sqrt(datos.i) , datos.d)
plt.plot(x , y)

# %% [markdown]
# # apartado c

# %%
col = ['i' , 'd']

datos = pd.read_table('7-34-c-app.dat', sep= "\s+" , names = col , header = None)
datos
# Out:
#             i             d
# 0           1      5.296839
# 1           2      9.302807
# 2           3      8.289393
# 3           4     12.713847
# 4           5     12.735678
# ...       ...           ...
# 99995   99996  74266.406200
# 99996   99997  74266.007800
# 99997   99998  74265.703100
# 99998   99999  74269.335900
# 99999  100000  74269.296900
#
# [100000 rows x 2 columns]

# %%
plt.figure(figsize = (16,9))

plt.plot(datos.i , datos.d)
